# %% [markdown]
# ## Learning how to use psql in python
# https://towardsdatascience.com/python-and-postgresql-how-to-access-a-postgresql-database-like-a-data-scientist-b5a9c5a0ea43

# %%
#!brew install postgresql
#!pip install psycopg2
# Out:
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/68.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:ba2fd8c7d370
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/manifests/1.1.1k
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/blobs/sha256:17d94c
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/krb5/manifests/1.19.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/krb5/blobs/sha256:d544c1111503e
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/manifests/8.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/blobs/sha256:2cc3a9582
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/postgresql/manifests/13.2_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/postgresql/blobs/sha256:67a5478
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Installing dependencies for postgresql: icu4c, openssl@1.1, krb5 and readline
# ==> Installing postgresql dependency: icu4c
# ==> Pouring icu4c--68.2.big_sur.bottle.tar.gz
# ==> Caveats
# icu4c is keg-only, which means it was not symlinked into /usr/local,
# because macOS provides libicucore.dylib (but nothing else).
#
# If you need to have icu4c first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/icu4c/bin:$PATH"' >> /Users/cade/.bash_profile
#   echo 'export PATH="/usr/local/opt/icu4c/sbin:$PATH"' >> /Users/cade/.bash_profile
#
# For compilers to find icu4c you may need to set:
#   export LDFLAGS="-L/usr/local/opt/icu4c/lib"
#   export CPPFLAGS="-I/usr/local/opt/icu4c/include"
#
# For pkg-config to find icu4c you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/icu4c/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/icu4c/68.2: 259 files, 72.5MB
# ==> Installing postgresql dependency: openssl@1.1
# ==> Pouring openssl@1.1--1.1.1k.big_sur.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# ==> Caveats
# A CA file has been bootstrapped using certificates from the system
# keychain. To add additional certificates, place .pem files in
#   /usr/local/etc/openssl@1.1/certs
#
# and run
#   /usr/local/opt/openssl@1.1/bin/c_rehash
#
# openssl@1.1 is keg-only, which means it was not symlinked into /usr/local,
# because macOS provides LibreSSL.
#
# If you need to have openssl@1.1 first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/openssl@1.1/bin:$PATH"' >> /Users/cade/.bash_profile
#
# For compilers to find openssl@1.1 you may need to set:
#   export LDFLAGS="-L/usr/local/opt/openssl@1.1/lib"
#   export CPPFLAGS="-I/usr/local/opt/openssl@1.1/include"
#
# For pkg-config to find openssl@1.1 you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/openssl@1.1/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/openssl@1.1/1.1.1k: 8,071 files, 18.5MB
# ==> Installing postgresql dependency: krb5
# ==> Pouring krb5--1.19.1.big_sur.bottle.tar.gz
# ==> Caveats
# krb5 is keg-only, which means it was not symlinked into /usr/local,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# If you need to have krb5 first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/krb5/bin:$PATH"' >> /Users/cade/.bash_profile
#   echo 'export PATH="/usr/local/opt/krb5/sbin:$PATH"' >> /Users/cade/.bash_profile
#
# For compilers to find krb5 you may need to set:
#   export LDFLAGS="-L/usr/local/opt/krb5/lib"
#   export CPPFLAGS="-I/usr/local/opt/krb5/include"
#
# For pkg-config to find krb5 you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/krb5/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/krb5/1.19.1: 162 files, 5.2MB
# ==> Installing postgresql dependency: readline
# ==> Pouring readline--8.1.big_sur.bottle.tar.gz
# ==> Caveats
# readline is keg-only, which means it was not symlinked into /usr/local,
# because macOS provides BSD libedit.
#
# For compilers to find readline you may need to set:
#   export LDFLAGS="-L/usr/local/opt/readline/lib"
#   export CPPFLAGS="-I/usr/local/opt/readline/include"
#
# For pkg-config to find readline you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/readline/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/readline/8.1: 48 files, 1.6MB
# ==> Installing postgresql
# ==> Pouring postgresql--13.2_1.big_sur.bottle.tar.gz
# ==> /usr/local/Cellar/postgresql/13.2_1/bin/initdb --locale=C -E UTF-8 /usr/loca
# ==> Caveats
# To migrate existing data from a previous major version of PostgreSQL run:
#   brew postgresql-upgrade-database
#
# This formula has created a default database cluster with:
#   initdb --locale=C -E UTF-8 /usr/local/var/postgres
# For more details, read:
#   https://www.postgresql.org/docs/13/app-initdb.html
#
# To have launchd start postgresql now and restart at login:
#   brew services start postgresql
# Or, if you don't want/need a background service you can just run:
#   pg_ctl -D /usr/local/var/postgres start
# ==> Summary
# 🍺  /usr/local/Cellar/postgresql/13.2_1: 3,218 files, 42.6MB
# ==> `brew cleanup` has not been run in 30 days, running now...
# Removing: /Users/cade/Library/Caches/Homebrew/cairo--1.16.0_3.big_sur.bottle.tar.gz... (1.6MB)
# Removing: /Users/cade/Library/Caches/Homebrew/fontconfig--2.13.1.big_sur.bottle.tar.gz... (1.2MB)
# Removing: /Users/cade/Library/Caches/Homebrew/freetype--2.10.4.big_sur.bottle.tar.gz... (901.3KB)
# Removing: /Users/cade/Library/Caches/Homebrew/fribidi--1.0.10.big_sur.bottle.tar.gz... (130.9KB)
# Removing: /Users/cade/Library/Caches/Homebrew/gd--2.3.0.big_sur.bottle.tar.gz... (300.9KB)
# Removing: /Users/cade/Library/Caches/Homebrew/gdbm--1.18.1_1.big_sur.bottle.tar.gz... (207.3KB)
# Removing: /Users/cade/Library/Caches/Homebrew/gdk-pixbuf--2.42.0.big_sur.bottle.tar.gz... (799KB)
# Removing: /Users/cade/Library/Caches/Homebrew/gettext--0.21.big_sur.bottle.tar.gz... (8.5MB)
# Removing: /Users/cade/Library/Caches/Homebrew/glib--2.66.2_1.big_sur.bottle.tar.gz... (4.5MB)
# Removing: /Users/cade/Library/Caches/Homebrew/gobject-introspection--1.66.1_1.big_sur.bottle.tar.gz... (1.8MB)
# Removing: /Users/cade/Library/Caches/Homebrew/graphite2--1.3.14.big_sur.bottle.tar.gz... (93.4KB)
# Removing: /Users/cade/Library/Caches/Homebrew/graphviz--2.44.1.big_sur.bottle.1.tar.gz... (12.9MB)
# Removing: /Users/cade/Library/Caches/Homebrew/gts--0.7.6_2.big_sur.bottle.tar.gz... (401.4KB)
# Removing: /Users/cade/Library/Caches/Homebrew/harfbuzz--2.7.2.big_sur.bottle.tar.gz... (1.9MB)
# Removing: /usr/local/Cellar/icu4c/67.1... (258 files, 71.2MB)
# Removing: /Users/cade/Library/Caches/Homebrew/jasper--2.0.22.big_sur.bottle.tar.gz... (663.8KB)
# Removing: /Users/cade/Library/Caches/Homebrew/jpeg--9d.big_sur.bottle.tar.gz... (311.5KB)
# Removing: /Users/cade/Library/Caches/Homebrew/libffi--3.3.big_sur.bottle.tar.gz... (167KB)
# Removing: /Users/cade/Library/Caches/Homebrew/libpng--1.6.37.big_sur.bottle.tar.gz... (443.3KB)
# Removing: /Users/cade/Library/Caches/Homebrew/librsvg--2.50.2.big_sur.bottle.tar.gz... (38.3MB)
# Removing: /Users/cade/Library/Caches/Homebrew/libtiff--4.1.0_1.big_sur.bottle.tar.gz... (1.1MB)
# Removing: /Users/cade/Library/Caches/Homebrew/libtool--2.4.6_2.big_sur.bottle.tar.gz... (1014.1KB)
# Removing: /Users/cade/Library/Caches/Homebrew/lzo--2.10.big_sur.bottle.tar.gz... (144.9KB)
# Removing: /Users/cade/Library/Caches/Homebrew/netpbm--10.86.17.big_sur.bottle.tar.gz... (1.8MB)
# Removing: /usr/local/Cellar/openssl@1.1/1.1.1h... (8,067 files, 18.5MB)
# Removing: /Users/cade/Library/Caches/Homebrew/openssl@1.1--1.1.1h.big_sur.bottle.tar.gz... (5.4MB)
# Removing: /Users/cade/Library/Caches/Homebrew/pango--1.48.0.big_sur.bottle.tar.gz... (733.4KB)
# Removing: /Users/cade/Library/Caches/Homebrew/pcre--8.44.big_sur.bottle.tar.gz... (1.8MB)
# Removing: /Users/cade/Library/Caches/Homebrew/pixman--0.40.0.big_sur.bottle.tar.gz... (508.3KB)
# Removing: /Users/cade/Library/Caches/Homebrew/pkg-config--0.29.2_3.big_sur.bottle.tar.gz... (239.6KB)
# Removing: /Users/cade/Library/Caches/Homebrew/python@3.9--3.9.0_4.big_sur.bottle.1.tar.gz... (17.9MB)
# Removing: /usr/local/Cellar/readline/8.0.4... (48 files, 1.6MB)
# Removing: /Users/cade/Library/Caches/Homebrew/readline--8.0.4.big_sur.bottle.tar.gz... (519.8KB)
# Removing: /Users/cade/Library/Caches/Homebrew/sqlite--3.34.0.big_sur.bottle.tar.gz... (2.0MB)
# Removing: /Users/cade/Library/Caches/Homebrew/webp--1.1.0.big_sur.bottle.tar.gz... (869.8KB)
# Removing: /Users/cade/Library/Caches/Homebrew/xz--5.2.5.big_sur.bottle.tar.gz... (417.6KB)
# Removing: /Users/cade/Library/Logs/Homebrew/pkg-config... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/libtiff... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/libtool... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/libpng... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/pixman... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/gdbm... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/freetype... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/gts... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/pango... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/gdk-pixbuf... (204B)
# Removing: /Users/cade/Library/Logs/Homebrew/harfbuzz... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/glib... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/readline... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/netpbm... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/graphite2... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/cairo... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/webp... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/sqlite... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/gobject-introspection... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/fribidi... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/xz... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/fontconfig... (1KB)
# Removing: /Users/cade/Library/Logs/Homebrew/gettext... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/librsvg... (194B)
# Removing: /Users/cade/Library/Logs/Homebrew/graphviz... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/gd... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/openssl@1.1... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/pcre... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/jpeg... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/jasper... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/lzo... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/libffi... (64B)
# Removing: /Users/cade/Library/Logs/Homebrew/python@3.9... (3 files, 176.7KB)
# Pruned 1 symbolic links and 2 directories from /usr/local
# ==> Upgrading 12 dependents:
# cairo 1.16.0_3 -> 1.16.0_5, gdk-pixbuf 2.42.0 -> 2.42.6, glib 2.66.2_1 -> 2.68.1, gobject-introspection 1.66.1_1 -> 1.68.0, harfbuzz 2.7.2 -> 2.8.0, node 14.4.0 -> 15.14.0, pango 1.48.0 -> 1.48.4, sqlite 3.34.0 -> 3.35.4, python@3.9 3.9.0_4 -> 3.9.4, librsvg 2.50.2 -> 2.50.4, graphviz 2.44.1 -> 2.47.0, yarn 1.22.4 -> 1.22.10
# ==> Upgrading sqlite 3.34.0 -> 3.35.4
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.35.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:861dc044ea5
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Pouring sqlite--3.35.4.big_sur.bottle.tar.gz
# ==> Caveats
# sqlite is keg-only, which means it was not symlinked into /usr/local,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# If you need to have sqlite first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/sqlite/bin:$PATH"' >> /Users/cade/.bash_profile
#
# For compilers to find sqlite you may need to set:
#   export LDFLAGS="-L/usr/local/opt/sqlite/lib"
#   export CPPFLAGS="-I/usr/local/opt/sqlite/include"
#
# For pkg-config to find sqlite you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/sqlite/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/sqlite/3.35.4: 11 files, 4.2MB
# Removing: /usr/local/Cellar/sqlite/3.34.0... (11 files, 4.1MB)
# ==> Upgrading gdk-pixbuf 2.42.0 -> 2.42.6
# ==> Downloading https://ghcr.io/v2/homebrew/core/libffi/manifests/3.3_3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libffi/blobs/sha256:8a7a02cffb3
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/manifests/1.19
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/blobs/sha256:3581501b051db
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpdecimal/manifests/2.5.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpdecimal/blobs/sha256:255b6226
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/manifests/3.9.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/blobs/sha256:77ba90d
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.68.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:244628aa2804c
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.2.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:31dc53e161
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/manifests/2.42.6
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/blobs/sha256:f4cf795
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Installing dependencies for gdk-pixbuf: libffi, gdbm, mpdecimal, python@3.9, glib and libtiff
# ==> Installing gdk-pixbuf dependency: libffi
# ==> Pouring libffi--3.3_3.big_sur.bottle.tar.gz
# ==> Caveats
# libffi is keg-only, which means it was not symlinked into /usr/local,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# For compilers to find libffi you may need to set:
#   export LDFLAGS="-L/usr/local/opt/libffi/lib"
#   export CPPFLAGS="-I/usr/local/opt/libffi/include"
#
# For pkg-config to find libffi you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/libffi/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/libffi/3.3_3: 17 files, 540.5KB
# ==> Installing gdk-pixbuf dependency: gdbm
# ==> Pouring gdbm--1.19.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/gdbm/1.19: 24 files, 791.3KB
# ==> Installing gdk-pixbuf dependency: mpdecimal
# ==> Pouring mpdecimal--2.5.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/mpdecimal/2.5.1: 71 files, 2.1MB
# ==> Installing gdk-pixbuf dependency: python@3.9
# ==> Pouring python@3.9--3.9.4.big_sur.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /usr/local
# Could not symlink bin/2to3
# Target /usr/local/bin/2to3
# already exists. You may want to remove it:
#   rm '/usr/local/bin/2to3'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite python@3.9
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run python@3.9
#
# Possible conflicting files are:
# /usr/local/bin/2to3 -> /Library/Frameworks/Python.framework/Versions/3.7/bin/2to3
# /usr/local/bin/idle3 -> /Library/Frameworks/Python.framework/Versions/3.7/bin/idle3
# /usr/local/bin/pydoc3 -> /Library/Frameworks/Python.framework/Versions/3.7/bin/pydoc3
# /usr/local/bin/python3 -> /Library/Frameworks/Python.framework/Versions/3.7/bin/python3
# /usr/local/bin/python3-config -> /Library/Frameworks/Python.framework/Versions/3.7/bin/python3-config
# ==> /usr/local/Cellar/python@3.9/3.9.4/bin/python3 -m ensurepip
# ==> /usr/local/Cellar/python@3.9/3.9.4/bin/python3 -m pip install -v --no-deps -
# ==> Caveats
# Python has been installed as
#   /usr/local/bin/python3
#
# Unversioned symlinks `python`, `python-config`, `pip` etc. pointing to
# `python3`, `python3-config`, `pip3` etc., respectively, have been installed into
#   /usr/local/opt/python@3.9/libexec/bin
#
# You can install Python packages with
#   pip3 install <package>
# They will install into the site-package directory
#   /usr/local/lib/python3.9/site-packages
#
# tkinter is no longer included with this formula, but it is available separately:
#   brew install python-tk@3.9
#
# See: https://docs.brew.sh/Homebrew-and-Python
# ==> Summary
# 🍺  /usr/local/Cellar/python@3.9/3.9.4: 3,047 files, 54.2MB
# ==> Installing gdk-pixbuf dependency: glib
# ==> Pouring glib--2.68.1.big_sur.bottle.tar.gz
# ==> Caveats
# Bash completion has been installed to:
#   /usr/local/etc/bash_completion.d
# ==> Summary
# 🍺  /usr/local/Cellar/glib/2.68.1: 442 files, 21MB
# ==> Installing gdk-pixbuf dependency: libtiff
# ==> Pouring libtiff--4.2.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libtiff/4.2.0: 248 files, 4.4MB
# ==> Installing gdk-pixbuf
# ==> Pouring gdk-pixbuf--2.42.6.big_sur.bottle.tar.gz
# ==> /usr/local/Cellar/gdk-pixbuf/2.42.6/bin/gdk-pixbuf-query-loaders --update-ca
# 🍺  /usr/local/Cellar/gdk-pixbuf/2.42.6: 147 files, 3.7MB
# Removing: /usr/local/Cellar/gdk-pixbuf/2.42.0... (149 files, 3.8MB)
# ==> Upgrading glib 2.68.1 -> 2.68.1
# Removing: /usr/local/Cellar/glib/2.66.2_1... (436 files, 15.5MB)
# ==> Upgrading gobject-introspection 1.66.1_1 -> 1.68.0
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpthread-stubs/manifests/0.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpthread-stubs/blobs/sha256:9
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2021.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:33a7f790
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.9
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:b21411d706c
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:87be4ae90
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.14_1-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:990819c1dd5
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.7.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:8663963c852
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:8a037408ba
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.10
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:65fbad7
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.16.0_5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:cb16c1bb070a
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/manifests
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/blobs/sha
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Installing dependencies for gobject-introspection: libpthread-stubs, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender and cairo
# ==> Installing gobject-introspection dependency: libpthread-stubs
# ==> Pouring libpthread-stubs--0.4.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libpthread-stubs/0.4: 5 files, 6.8KB
# ==> Installing gobject-introspection dependency: xorgproto
# ==> Pouring xorgproto--2021.3.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/xorgproto/2021.3: 264 files, 3.9MB
# ==> Installing gobject-introspection dependency: libxau
# ==> Pouring libxau--1.0.9.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxau/1.0.9: 20 files, 117.7KB
# ==> Installing gobject-introspection dependency: libxdmcp
# ==> Pouring libxdmcp--1.1.3.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxdmcp/1.1.3: 11 files, 125.4KB
# ==> Installing gobject-introspection dependency: libxcb
# ==> Pouring libxcb--1.14_1.big_sur.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/libxcb/1.14_1: 2,452 files, 6.9MB
# ==> Installing gobject-introspection dependency: libx11
# ==> Pouring libx11--1.7.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libx11/1.7.0: 1,055 files, 7MB
# ==> Installing gobject-introspection dependency: libxext
# ==> Pouring libxext--1.3.4.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxext/1.3.4: 87 files, 420.8KB
# ==> Installing gobject-introspection dependency: libxrender
# ==> Pouring libxrender--0.9.10.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxrender/0.9.10: 12 files, 169.8KB
# ==> Installing gobject-introspection dependency: cairo
# ==> Pouring cairo--1.16.0_5.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/cairo/1.16.0_5: 126 files, 6.3MB
# ==> Installing gobject-introspection
# ==> Pouring gobject-introspection--1.68.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/gobject-introspection/1.68.0: 190 files, 12.7MB
# Removing: /usr/local/Cellar/gobject-introspection/1.66.1_1... (191 files, 12.7MB)
# ==> Upgrading harfbuzz 2.7.2 -> 2.8.0
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/2.8.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:e3178e183
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Pouring harfbuzz--2.8.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/harfbuzz/2.8.0: 68 files, 6.9MB
# Removing: /usr/local/Cellar/harfbuzz/2.7.2... (68 files, 6.4MB)
# ==> Upgrading node 14.4.0 -> 15.14.0
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.0.9
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:9d3009fd246
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/manifests/1.17.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/blobs/sha256:514de64e48f
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/manifests/1.41.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/blobs/sha256:74240126a16d
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jemalloc/manifests/5.2.1_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jemalloc/blobs/sha256:7797788be
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libev/manifests/4.33
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libev/blobs/sha256:95ddf4b85924
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nghttp2/manifests/1.43.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nghttp2/blobs/sha256:e6112c4ce4
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/manifests/15.14.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/blobs/sha256:5663d5e86b6e9
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Installing dependencies for node: brotli, c-ares, libuv, jemalloc, libev and nghttp2
# ==> Installing node dependency: brotli
# ==> Pouring brotli--1.0.9.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/brotli/1.0.9: 25 files, 2.4MB
# ==> Installing node dependency: c-ares
# ==> Pouring c-ares--1.17.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/c-ares/1.17.1: 85 files, 672.5KB
# ==> Installing node dependency: libuv
# ==> Pouring libuv--1.41.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libuv/1.41.0: 49 files, 3.1MB
# ==> Installing node dependency: jemalloc
# ==> Pouring jemalloc--5.2.1_1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/jemalloc/5.2.1_1: 16 files, 2MB
# ==> Installing node dependency: libev
# ==> Pouring libev--4.33.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libev/4.33: 12 files, 484.0KB
# ==> Installing node dependency: nghttp2
# ==> Pouring nghttp2--1.43.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/nghttp2/1.43.0: 24 files, 2.8MB
# ==> Installing node
# ==> Pouring node--15.14.0.big_sur.bottle.tar.gz
# ==> Caveats
# Bash completion has been installed to:
#   /usr/local/etc/bash_completion.d
# ==> Summary
# 🍺  /usr/local/Cellar/node/15.14.0: 2,808 files, 48.8MB
# Removing: /usr/local/Cellar/node/14.4.0... (4,659 files, 60.8MB)
# ==> Upgrading pango 1.48.0 -> 1.48.4
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.48.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:f8f7b4985861
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Pouring pango--1.48.4.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/pango/1.48.4: 64 files, 2.9MB
# Removing: /usr/local/Cellar/pango/1.48.0... (64 files, 3MB)
# ==> Upgrading python@3.9 3.9.4 -> 3.9.4
# Removing: /usr/local/Cellar/python@3.9/3.9.0_4... (4,452 files, 72.2MB)
# ==> Upgrading librsvg 2.50.2 -> 2.50.4
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.50.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/blobs/sha256:80662bd892
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Pouring librsvg--2.50.4.big_sur.bottle.tar.gz
# ==> /usr/local/opt/gdk-pixbuf/bin/gdk-pixbuf-query-loaders --update-cache
# 🍺  /usr/local/Cellar/librsvg/2.50.4: 48 files, 148.5MB
# Removing: /usr/local/Cellar/librsvg/2.50.2... (48 files, 141MB)
# ==> Upgrading graphviz 2.44.1 -> 2.47.0
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.2.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:1099da9d890c8
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/manifests/2.3.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/blobs/sha256:2c746f463d1b0ce
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/2.0.32
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:3b56f3d1d58
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/10.86.21
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:ccc6fd7b673
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/manifests/1.4.18-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/blobs/sha256:0df9083b268f76a
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.4.6_3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:a70ed5b9d7
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/2.47.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:7972126b7
# ==> Downloading from https://pkg-containers-az.githubusercontent.com/ghcr1/blobs
# ######################################################################## 100.0%
# ==> Installing dependencies for graphviz: webp, gd, jasper, netpbm, m4 and libtool
# ==> Installing graphviz dependency: webp
# ==> Pouring webp--1.2.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/webp/1.2.0: 39 files, 2.4MB
# ==> Installing graphviz dependency: gd
# ==> Pouring gd--2.3.2.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/gd/2.3.2: 35 files, 1.4MB
# ==> Installing graphviz dependency: jasper
# ==> Pouring jasper--2.0.32.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/jasper/2.0.32: 40 files, 1018.8KB
# ==> Installing graphviz dependency: netpbm
# ==> Pouring netpbm--10.86.21.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/netpbm/10.86.21: 410 files, 17.7MB
# ==> Installing graphviz dependency: m4
# ==> Pouring m4--1.4.18.big_sur.bottle.1.tar.gz
# ==> Caveats
# m4 is keg-only, which means it was not symlinked into /usr/local,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# If you need to have m4 first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/m4/bin:$PATH"' >> /Users/cade/.bash_profile
#
# ==> Summary
# 🍺  /usr/local/Cellar/m4/1.4.18: 13 files, 672.3KB
# ==> Installing graphviz dependency: libtool
# ==> Pouring libtool--2.4.6_3.big_sur.bottle.tar.gz
# ==> Caveats
# In order to prevent conflicts with Apple's own libtool we have prepended a "g"
# so, you have instead: glibtool and glibtoolize.
# ==> Summary
# 🍺  /usr/local/Cellar/libtool/2.4.6_3: 71 files, 3.7MB
# ==> Installing graphviz
# ==> Pouring graphviz--2.47.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/graphviz/2.47.0: 301 files, 10.5MB
# Removing: /usr/local/Cellar/graphviz/2.44.1... (508 files, 19.2MB)
# ==> Upgrading cairo 1.16.0_5 -> 1.16.0_5
# Removing: /usr/local/Cellar/cairo/1.16.0_3... (119 files, 5.9MB)
# ==> Upgrading yarn 1.22.4 -> 1.22.10
# ==> Downloading https://yarnpkg.com/downloads/1.22.10/yarn-v1.22.10.tar.gz
# ==> Downloading from https://github-releases.githubusercontent.com/49970642/30fd
# ######################################################################## 100.0%
# Error: Your Command Line Tools (CLT) does not support macOS 11.
# It is either outdated or was modified.
# Please update your Command Line Tools (CLT) or delete it if no updates are available.
# Update them from Software Update in System Preferences or run:
#   softwareupdate --all --install --force
#
# If that doesn't show you any updates, run:
#   sudo rm -rf /Library/Developer/CommandLineTools
#   sudo xcode-select --install
#
# Alternatively, manually download them from:
#   https://developer.apple.com/download/more/.
#
# Error: An exception occurred within a child process:
#   SystemExit: exit

# %%
# This gist contains a direct connection to a local PostgreSQL database
# called "suppliers" where the username and password parameters are "postgres"

# This code is adapted from the tutorial hosted below:
# http://www.postgresqltutorial.com/postgresql-python/connect/

import psycopg2

# Establish a connection to the database by creating a cursor object
# The PostgreSQL server must be accessed through the PostgreSQL APP or Terminal Shell
conn = psycopg2.connect(host="codd.mines.edu", port = 5433, database="csci403", user="ccrandall",                 password="")

# Create a cursor object
cur = conn.cursor()

# make the query on the cursor
cur.execute("""SELECT * FROM mines_cs_faculty""")

# fetch results from cursor
query_results = cur.fetchall()


print(query_results)

# Close the cursor and connection to so the server can allocate
# bandwidth to other requests
cur.close()
conn.close()
# Out:
# [('Han, Qi', 'BB 280H', 'qhan@mines.edu'), ('Paone, Jeffrey', 'BB 280C', 'jpaone@mines.edu'), ('Wang, Hua', 'BB 280F', 'huawang@mines.edu'), ('Yang, Dejun', 'BB 280G', 'djyang@mines.edu'), ('Yue, Chuan', 'BB 248', 'chuanyue@mines.edu'), ('Camp, Tracy', 'BB 280E', 'tcamp@mines.edu'), ('Dantam, Neil', 'BB 249', 'ndantam@mines.edu'), ('Fisher, Wendy', 'BB 280D', 'wfisher@mines.edu'), ('Mehta, Dinesh', 'BB 280J', 'dmehta@mines.edu'), ('Williams, Thomas', 'BB 254A', 'twilliams@mines.edu'), ('Wu, Bo', 'BB 247', 'bwu@mines.edu'), ('Zhang, Hao', 'BB 250', 'hzhang@mines.edu'), ('Baldwin, Mark', 'BB 312', 'baldwin@mines.edu'), ('Dave, Vibhuti', 'BB 314C', 'vdave@mines.edu'), ('Hoff, William', 'BB 249', 'whoff@mines.edu'), ('Painter-Wakefield, Christopher', 'BB 280N', 'cpainter@mines.edu'), ('Rader, Cynthia', None, 'crader@mines.edu'), ('Hammer, M.C.', 'BB 280E', 'canttouchthis@mines.edu')]

# %%
import pandas as pd

df = pd.DataFrame(query_results)

# %%
df
# Out:
#                                  0        1                        2
# 0                          Han, Qi  BB 280H           qhan@mines.edu
# 1                   Paone, Jeffrey  BB 280C         jpaone@mines.edu
# 2                        Wang, Hua  BB 280F        huawang@mines.edu
# 3                      Yang, Dejun  BB 280G         djyang@mines.edu
# 4                       Yue, Chuan   BB 248       chuanyue@mines.edu
# 5                      Camp, Tracy  BB 280E          tcamp@mines.edu
# 6                     Dantam, Neil   BB 249        ndantam@mines.edu
# 7                    Fisher, Wendy  BB 280D        wfisher@mines.edu
# 8                    Mehta, Dinesh  BB 280J         dmehta@mines.edu
# 9                 Williams, Thomas  BB 254A      twilliams@mines.edu
# 10                          Wu, Bo   BB 247            bwu@mines.edu
# 11                      Zhang, Hao   BB 250         hzhang@mines.edu
# 12                   Baldwin, Mark   BB 312        baldwin@mines.edu
# 13                   Dave, Vibhuti  BB 314C          vdave@mines.edu
# 14                   Hoff, William   BB 249          whoff@mines.edu
# 15  Painter-Wakefield, Christopher  BB 280N       cpainter@mines.edu
# 16                  Rader, Cynthia     None         crader@mines.edu
# 17                    Hammer, M.C.  BB 280E  canttouchthis@mines.edu
