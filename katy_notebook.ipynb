# %% [markdown]
# ## Learning how to use psql in python
# https://towardsdatascience.com/python-and-postgresql-how-to-access-a-postgresql-database-like-a-data-scientist-b5a9c5a0ea43

# %%
from getpass import getpass
import pandas as pd
import numpy as np

username = input("Username: ")
password = getpass("Password: ")

dburi = f'postgresql://{username}:{password}@codd.mines.edu:5433/csci403'
# Out:
# Username: kjendrzey
# Password: ········

# %%
query3 = "SELECT * FROM kjendrzey.katy_final"

# %%
df = pd.read_sql_query(query3, con=dburi)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# /opt/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# /opt/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

df = pd.DataFrame(df, columns = df.columns)

plt.xlabel("time"), plt.ylabel("features")
plt.plot(df['id'], df['count'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('Percentage of Features per Genre since 1999')
genre = ['Rap', 'Pop', 'Country', 'Rock']
num = [7.05,6.37,3.52,2.41]
ax.bar(genre,num)
plt.show()
